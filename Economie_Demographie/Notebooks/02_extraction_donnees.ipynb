# %% [markdown]
# # Compagnon Immobilier - Économie & Démographie
#
# ## Extraction des données INSEE
#
# ---
#
# Dans ce notebook, nous récupérons les données économiques et démographiques via l'API de l'INSEE (bibliothèque `pynsee`).

# %% [markdown]
# ## 1. Configuration et Imports

# %%
# Imports standards
import os
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Imports pynsee
from pynsee.macrodata import get_dataset_list, get_series_list, get_series
from pynsee.localdata import get_local_data

# Configuration des chemins
PROJECT_ROOT = os.path.dirname(os.getcwd())  # Racine = Economie_Demographie
DATA_DIR = os.path.join(PROJECT_ROOT, 'data')

# Créer le dossier si nécessaire
os.makedirs(DATA_DIR, exist_ok=True)

print(f"Dossier de données : {DATA_DIR}")
print(f"Date d'exécution : {datetime.now().strftime('%Y-%m-%d %H:%M')}")
# Out:
# Dossier de données : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data
# Date d'exécution : 2025-12-24 12:49

# %% [markdown]
# ## 2. Fonctionnement de pynsee
#
# L'API pynsee propose deux modules principaux :
#
# | Module | Fonction | Usage |
# |--------|----------|-------|
# | `macrodata` | `get_dataset_list()` | Liste des datasets macro disponibles |
# | `macrodata` | `get_series_list(dataset)` | Séries temporelles d'un dataset |
# | `macrodata` | `get_series(series_id)` | Données d'une série spécifique |
# | `localdata` | `get_local_data()` | Données locales (départements, communes) |

# %%
# Explorer les datasets disponibles
datasets = get_dataset_list()
print(f"Nombre total de datasets : {len(datasets)}")
print(f"\nColonnes disponibles : {datasets.columns.tolist()}")
print("\n" + "="*80)
print("Premiers datasets :")
print("="*80)
datasets[['id', 'Name.fr', 'n_series']].head(10)
# Out:
# Nombre total de datasets : 226
#
# Colonnes disponibles : ['id', 'Name.fr', 'Name.en', 'url', 'n_series']
#
# ================================================================================
# Premiers datasets :
# ================================================================================
#                       id                                            Name.fr  \
# 0      BALANCE-PAIEMENTS                              Balance des paiements
# 1  CHOMAGE-TRIM-NATIONAL  Chômage, taux de chômage par sexe et âge (sens...
# 2        CLIMAT-AFFAIRES    Indicateurs synthétiques du climat des affaires
# 3     CNA-2010-CONSO-MEN  Consommation des ménages - Résultats par produ...
# 4      CNA-2010-CONSO-SI  Dépenses de consommation finale par secteur in...
# 5          CNA-2010-CPEB  Comptes de production et d’exploitation par br...
# 6           CNA-2010-CSI  Comptes des secteurs institutionnels - Résulta...
# 7       CNA-2010-DEP-APU  Dépenses des administrations publiques - Résul...
# 8     CNA-2010-DETTE-APU  Dette et déficit des administrations publiques...
# 9        CNA-2010-EMPLOI  Emploi intérieur, durée effective travaillée e...
#
#    n_series
# 0       197
# 1       169
# 2         3
# 3      2247
# 4      1391
# 5      2739
# 6      1173
# 7      4400
# 8        72
# 9       702

# %% [markdown]
# ### 2.2 Recherche de datasets pertinents
#
# Nous recherchons les datasets en lien avec notre problématique immobilière :

# %%
# Fonction de recherche dans les datasets
def rechercher_datasets(mot_cle):
    """Recherche des datasets contenant un mot-clé."""
    mask = datasets['Name.fr'].str.lower().str.contains(mot_cle.lower(), na=False)
    resultats = datasets[mask][['id', 'Name.fr', 'n_series']]
    print(f"Recherche '{mot_cle}' : {len(resultats)} résultat(s)")
    return resultats

# Recherches pertinentes pour l'immobilier
print("=" * 80)
print("DATASETS PERTINENTS POUR L'IMMOBILIER")
print("=" * 80)

for terme in ['chomage', 'pib', 'prix', 'population', 'revenu', 'logement', 'inflation']:
    print(f"\n--- {terme.upper()} ---")
    display(rechercher_datasets(terme))
# Out:
# ================================================================================
# DATASETS PERTINENTS POUR L'IMMOBILIER
# ================================================================================
#
# --- CHOMAGE ---
# Recherche 'chomage' : 0 résultat(s)
# Empty DataFrame
# Columns: [id, Name.fr, n_series]
# Index: []
# --- PIB ---
# Recherche 'pib' : 3 résultat(s)
#               id                                            Name.fr  n_series
# 14  CNA-2010-PIB  Produit intérieur brut (PIB) et ses composante...        34
# 29  CNA-2014-PIB    Produit intérieur brut (PIB) et ses composantes        25
# 40  CNA-2020-PIB    Produit intérieur brut (PIB) et ses composantes        21
# --- PRIX ---
# Recherche 'prix' : 29 résultat(s)
#                           id  \
# 111  IP-PROD-CONS-N-HAB-2010
# 112  IP-PROD-CONS-N-HAB-2015
# 113  IP-PROD-CONS-N-HAB-2021
# 114                   IPAGRI
# 115         IPAGRI-BASE-2015
# 116         IPAGRI-BASE-2020
# 117            IPC-1970-1980
# 118                 IPC-1990
# 119                 IPC-1998
# 120                 IPC-2015
# 121              IPC-PM-2015
# 122                IPCH-2005
# 123                IPCH-2015
# 124                IPEA-2010
# 125                IPEA-2015
# 126                IPEA-2021
# 127                IPGD-1998
# 128                IPGD-2015
# 134          IPLA-IPLNA-2010
# 135          IPLA-IPLNA-2015
# 136                IPPI-2005
# 137                IPPI-2010
# 138                IPPI-2015
# 139                IPPI-2021
# 140                    IPPMP
# 141                 IPPMP-NF
# 142                IPPS-2010
# 143                IPPS-2015
# 144                IPPS-2021
#
#                                                Name.fr  n_series
# 111  Indice des prix de production de la constructi...         1
# 112  Indice des prix de production de la constructi...         1
# 113  Indice des prix de production de la constructi...         1
# 114  Indices des prix dans l’agriculture - IPPAP, I...       851
# 115                Indices des prix dans l'agriculture       725
# 116                Indices des prix dans l'agriculture       899
# 117                 Indices des prix à la consommation       813
# 118                 Indices des prix à la consommation      1650
# 119  Indices des prix à la consommation - Résultats...      3133
# 120                 Indices des prix à la consommation      4225
# 121                     Prix moyens de vente de détail       307
# 122  Indices des prix à la consommation harmonisés ...       393
# 123      Indices des prix à la consommation harmonisés      1293
# 124  Indice des prix d’entretien-amélioration des l...        10
# 125  Indice des prix d'entretien-amélioration des b...        30
# 126  Indice des prix d'entretien-amélioration des b...        30
# 127       Indices des prix dans la grande distribution         9
# 128        Indice des prix dans la grande distribution        11
# 134  Indices des prix des logements neufs et indice...       112
# 135  Indices des prix des logements neufs et Indice...       142
# 136  Indices de prix de production et d'importation...      2571
# 137  Indices de prix de production et d'importation...      2493
# 138  Indices de prix de production et d'importation...      2288
# 139  Indices de prix de production et d'importation...      1919
# 140    Indices de prix et cours des matières premières       131
# 141    Indices de prix et cours des matières premières       161
# 142    Indice des prix de production dans les services       634
# 143    Indice des prix de production dans les services       627
# 144    Indice des prix de production dans les services       531
# --- POPULATION ---
# Recherche 'population' : 3 résultat(s)
#                                 id  \
# 168           POPULATION-STRUCTURE
# 181  TCRED-CONDITIONSDEVIE-APE-PEC
# 203   TCRED-ESTIMATIONS-POPULATION
#
#                                             Name.fr  n_series
# 168        Population et structure de la population        50
# 181  TCRED - Affaires pénales et population écrouée       704
# 203               TCRED - Estimations de population       819
# --- REVENU ---
# Recherche 'revenu' : 5 résultat(s)
#                                          id  \
# 15                             CNA-2010-RDB
# 30                             CNA-2014-RDB
# 204              TCRED-SALAIRES-REVENUS-MEN
# 206  TCRED-SALAIRES-REVENUS-REV-SAL-SEXE-CS
# 207    TCRED-SALAIRES-REVENUS-STRUCTURE-RDB
#
#                                                Name.fr  n_series
# 15   Revenu et pouvoir d’achat des ménages - Résult...        11
# 30               Revenu et pouvoir d’achat des ménages        12
# 204            TCRED - Revenus disponibles des ménages       565
# 206  TCRED - Revenu salarial annuel moyen selon la ...       819
# 207             TCRED - Structure du revenu disponible       565
# --- LOGEMENT ---
# Recherche 'logement' : 6 résultat(s)
#                                 id  \
# 61          CONSTRUCTION-LOGEMENTS
# 124                      IPEA-2010
# 134                IPLA-IPLNA-2010
# 135                IPLA-IPLNA-2015
# 167                 PARC-LOGEMENTS
# 183  TCRED-CONDITIONSDEVIE-LOG-SOC
#
#                                                Name.fr  n_series
# 61                           Construction de logements       608
# 124  Indice des prix d’entretien-amélioration des l...        10
# 134  Indices des prix des logements neufs et indice...       112
# 135  Indices des prix des logements neufs et Indice...       142
# 167  Estimations annuelles du parc de logements (EAPL)        26
# 183                          TCRED - Logements sociaux       468
# --- INFLATION ---
# Recherche 'inflation' : 0 résultat(s)
# Empty DataFrame
# Columns: [id, Name.fr, n_series]
# Index: []

# %% [markdown]
# ---
#
# ## 3. Données macroéconomiques
#
# ### 3.1 PIB (Produit Intérieur Brut)

# %%
# Exploration du dataset PIB
dataset_pib = 'CNT-2020-PIB-EQB-RF'

# Lister les séries disponibles
series_pib = get_series_list(dataset_pib)
print(f"Dataset : {dataset_pib}")
print(f"Nombre de séries : {len(series_pib)}")
print(f"\nColonnes : {series_pib.columns.tolist()}")
series_pib.head()
# Out:
# Dataset : CNT-2020-PIB-EQB-RF
# Nombre de séries : 68
#
# Colonnes : ['DATASET', 'IDBANK', 'KEY', 'FREQ', 'INDICATEUR', 'SECT_INST', 'OPERATION', 'CNA_PRODUIT', 'NATURE', 'REF_AREA', 'VALORISATION', 'UNIT_MEASURE', 'CORRECTION', 'SERIE_ARRETEE', 'FREQ_label_fr', 'FREQ_label_en', 'INDICATEUR_label_fr', 'INDICATEUR_label_en', 'SECT_INST_label_fr', 'SECT_INST_label_en', 'OPERATION_label_fr', 'OPERATION_label_en', 'CNA_PRODUIT_label_fr', 'CNA_PRODUIT_label_en', 'NATURE_label_fr', 'NATURE_label_en', 'REF_AREA_label_fr', 'REF_AREA_label_en', 'VALORISATION_label_fr', 'VALORISATION_label_en', 'UNIT_MEASURE_label_fr', 'UNIT_MEASURE_label_en', 'CORRECTION_label_fr', 'CORRECTION_label_en', 'SERIE_ARRETEE_label_fr', 'SERIE_ARRETEE_label_en']
#                DATASET     IDBANK  \
# 0  CNT-2020-PIB-EQB-RF  011794891
# 1  CNT-2020-PIB-EQB-RF  011794888
# 2  CNT-2020-PIB-EQB-RF  011794889
# 3  CNT-2020-PIB-EQB-RF  011794890
# 4  CNT-2020-PIB-EQB-RF  011794892
#
#                                                  KEY FREQ         INDICATEUR  \
# 0  T.CNT-EQUILIBRE_PIB.S15.P51P.D-CNT.VALEUR_ABSO...    T  CNT-EQUILIBRE_PIB
# 1  T.CNT-EQUILIBRE_PIB.S0.P51.D-CNT.VALEUR_ABSOLU...    T  CNT-EQUILIBRE_PIB
# 2  T.CNT-EQUILIBRE_PIB.S13.P51G.D-CNT.VALEUR_ABSO...    T  CNT-EQUILIBRE_PIB
# 3  T.CNT-EQUILIBRE_PIB.S14.P51M.D-CNT.VALEUR_ABSO...    T  CNT-EQUILIBRE_PIB
# 4  T.CNT-EQUILIBRE_PIB.S15.P3.SO.RATIO.FE.L.SO.CV...    T  CNT-EQUILIBRE_PIB
#
#   SECT_INST OPERATION CNA_PRODUIT          NATURE REF_AREA  ...  \
# 0       S15      P51P       D-CNT  VALEUR_ABSOLUE       FE  ...
# 1        S0       P51       D-CNT  VALEUR_ABSOLUE       FE  ...
# 2       S13      P51G       D-CNT  VALEUR_ABSOLUE       FE  ...
# 3       S14      P51M       D-CNT  VALEUR_ABSOLUE       FE  ...
# 4       S15        P3          SO           RATIO       FE  ...
#
#   REF_AREA_label_fr REF_AREA_label_en  \
# 0            France            France
# 1            France            France
# 2            France            France
# 3            France            France
# 4            France            France
#
#                             VALORISATION_label_fr  \
# 0                       Valeurs aux prix courants
# 1                       Valeurs aux prix courants
# 2                       Valeurs aux prix courants
# 3                       Valeurs aux prix courants
# 4  Volumes aux prix de l'année précédente chaînés
#
#                      VALORISATION_label_en UNIT_MEASURE_label_fr  \
# 0                 Values at current prices                 euros
# 1                 Values at current prices                 euros
# 2                 Values at current prices                 euros
# 3                 Values at current prices                 euros
# 4  Volumes chained at previous year prices            sans objet
#
#   UNIT_MEASURE_label_en                                CORRECTION_label_fr  \
# 0                 euros  Corrigé des variations saisonnières et du nomb...
# 1                 euros  Corrigé des variations saisonnières et du nomb...
# 2                 euros  Corrigé des variations saisonnières et du nomb...
# 3                 euros  Corrigé des variations saisonnières et du nomb...
# 4        not applicable  Corrigé des variations saisonnières et du nomb...
#
#                    CORRECTION_label_en SERIE_ARRETEE_label_fr  \
# 0  Seasonally and working-day adjusted                    non
# 1  Seasonally and working-day adjusted                    non
# 2  Seasonally and working-day adjusted                    non
# 3  Seasonally and working-day adjusted                    non
# 4  Seasonally and working-day adjusted                    non
#
#   SERIE_ARRETEE_label_en
# 0                     no
# 1                     no
# 2                     no
# 3                     no
# 4                     no
#
# [5 rows x 36 columns]

# %%
# Chargement ou extraction du PIB
fichier_pib = os.path.join(DATA_DIR, 'pib_france.csv')

if os.path.exists(fichier_pib):
    df_pib = pd.read_csv(fichier_pib)
    print(f"PIB chargé : {df_pib.shape[0]} lignes")
    print(f"Période : {df_pib['TIME_PERIOD'].min()} à {df_pib['TIME_PERIOD'].max()}")
else:
    idbanks_pib = series_pib['IDBANK'].tolist()
    df_pib = get_series(idbanks_pib)
    print(f"PIB extrait : {df_pib.shape}")

df_pib.head()
# Out:
# PIB chargé : 20435 lignes
# Période : 1949-Q1 à 2025-Q3
#   TIME_PERIOD  OBS_VALUE OBS_STATUS  OBS_REV OBS_QUAL OBS_TYPE    IDBANK FREQ  \
# 0     1950-Q2       1.71          A      NaN      DEF        A  11794832    T
# 1     1950-Q3       2.12          A      NaN      DEF        A  11794832    T
# 2     1950-Q4       1.17          A      NaN      DEF        A  11794832    T
# 3     1951-Q1       0.51          A      NaN      DEF        A  11794832    T
# 4     1951-Q2       1.64          A      NaN      DEF        A  11794832    T
#
#                                             TITLE_FR  \
# 0  Demande intérieure finale - Contribution à l'é...
# 1  Demande intérieure finale - Contribution à l'é...
# 2  Demande intérieure finale - Contribution à l'é...
# 3  Demande intérieure finale - Contribution à l'é...
# 4  Demande intérieure finale - Contribution à l'é...
#
#                                             TITLE_EN  ...  \
# 0  Final domestic demand - Contribution to GDP gr...  ...
# 1  Final domestic demand - Contribution to GDP gr...  ...
# 2  Final domestic demand - Contribution to GDP gr...  ...
# 3  Final domestic demand - Contribution to GDP gr...  ...
# 4  Final domestic demand - Contribution to GDP gr...  ...
#
#   SERIE_ARRETEE_label_fr SERIE_ARRETEE_label_en  OBS_STATUS_label_fr  \
# 0                    non                     no       Valeur normale
# 1                    non                     no       Valeur normale
# 2                    non                     no       Valeur normale
# 3                    non                     no       Valeur normale
# 4                    non                     no       Valeur normale
#
#   OBS_STATUS_label_en  OBS_REV_label_fr OBS_REV_label_en OBS_TYPE_label_fr  \
# 0        Normal value               NaN              NaN    Valeur normale
# 1        Normal value               NaN              NaN    Valeur normale
# 2        Normal value               NaN              NaN    Valeur normale
# 3        Normal value               NaN              NaN    Valeur normale
# 4        Normal value               NaN              NaN    Valeur normale
#
#   OBS_TYPE_label_en  OBS_QUAL_label_fr OBS_QUAL_label_en
# 0      Normal value  Valeur définitive       Final value
# 1      Normal value  Valeur définitive       Final value
# 2      Normal value  Valeur définitive       Final value
# 3      Normal value  Valeur définitive       Final value
# 4      Normal value  Valeur définitive       Final value
#
# [5 rows x 56 columns]

# %%
# Sauvegarde des données PIB
fichier_pib = os.path.join(DATA_DIR, 'pib_france.csv')
df_pib.to_csv(fichier_pib, index=False)
print(f"Fichier sauvegardé : {fichier_pib}")
print(f"Taille : {os.path.getsize(fichier_pib) / 1024:.1f} KB")
# Out:
# Fichier sauvegardé : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data/pib_france.csv
# Taille : 20239.9 KB

# %% [markdown]
# ### 3.2 IPC (Indice des Prix à la Consommation)

# %%
# Dataset IPC
dataset_ipc = 'IPC-2015'

series_ipc = get_series_list(dataset_ipc)
print(f"Dataset : {dataset_ipc}")
print(f"Nombre de séries : {len(series_ipc)}")
series_ipc.head()
# Out:
# Dataset : IPC-2015
# Nombre de séries : 4225
#     DATASET     IDBANK                                                KEY  \
# 0  IPC-2015  001765985  A.IPC.SO.045501.SO.POND.ENSEMBLE.FE.P10000.BRU...
# 1  IPC-2015  001765984  A.IPC.SO.04550.SO.POND.ENSEMBLE.FE.P10000.BRUT...
# 2  IPC-2015  001765983  A.IPC.SO.0455.SO.POND.ENSEMBLE.FE.P10000.BRUT....
# 3  IPC-2015  001765982  A.IPC.SO.045491.SO.POND.ENSEMBLE.FE.P10000.BRU...
# 4  IPC-2015  001765981  A.IPC.SO.04549.SO.POND.ENSEMBLE.FE.P10000.BRUT...
#
#   FREQ INDICATEUR FORME_VENTE COICOP2016 PRIX_CONSO NATURE MENAGES_IPC  ...  \
# 0    A        IPC          SO     045501         SO   POND    ENSEMBLE  ...
# 1    A        IPC          SO      04550         SO   POND    ENSEMBLE  ...
# 2    A        IPC          SO       0455         SO   POND    ENSEMBLE  ...
# 3    A        IPC          SO     045491         SO   POND    ENSEMBLE  ...
# 4    A        IPC          SO      04549         SO   POND    ENSEMBLE  ...
#
#   REF_AREA_label_fr REF_AREA_label_en UNIT_MEASURE_label_fr  \
# 0            France            France              1/10.000
# 1            France            France              1/10.000
# 2            France            France              1/10.000
# 3            France            France              1/10.000
# 4            France            France              1/10.000
#
#   UNIT_MEASURE_label_en CORRECTION_label_fr CORRECTION_label_en  \
# 0              1/10,000         Non corrigé         Uncorrected
# 1              1/10,000         Non corrigé         Uncorrected
# 2              1/10,000         Non corrigé         Uncorrected
# 3              1/10,000         Non corrigé         Uncorrected
# 4              1/10,000         Non corrigé         Uncorrected
#
#   BASIND_label_fr BASIND_label_en SERIE_ARRETEE_label_fr  \
# 0            2015            2015                    non
# 1            2015            2015                    non
# 2            2015            2015                    non
# 3            2015            2015                    non
# 4            2015            2015                    non
#
#   SERIE_ARRETEE_label_en
# 0                     no
# 1                     no
# 2                     no
# 3                     no
# 4                     no
#
# [5 rows x 39 columns]

# %%
# Chargement ou extraction des données IPC
fichier_ipc = os.path.join(DATA_DIR, 'ipc_france.csv')

if os.path.exists(fichier_ipc):
    df_ipc = pd.read_csv(fichier_ipc)
    print(f"IPC chargé : {df_ipc.shape[0]} lignes")
    print(f"Période : {df_ipc['TIME_PERIOD'].min()} à {df_ipc['TIME_PERIOD'].max()}")
else:
    # Trop de séries (4225) - on filtre sur l'indice général
    series_filtrees = series_ipc[
        (series_ipc['FREQ'] == 'M') &
        (series_ipc['COICOP2016'].isin(['00', '0']))
    ]
    idbanks_ipc = series_filtrees['IDBANK'].tolist()
    df_ipc = get_series(idbanks_ipc)
    print(f"IPC extrait : {df_ipc.shape}")

df_ipc.head()
# Out:
# IPC chargé : 431 lignes
# Période : 1990-01 à 2025-11
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_QUAL OBS_TYPE   IDBANK FREQ  \
# 0     1990-01      66.44          A      DEF        A  1763866    M
# 1     1990-02      66.58          A      DEF        A  1763866    M
# 2     1990-03      66.74          A      DEF        A  1763866    M
# 3     1990-04      67.11          A      DEF        A  1763866    M
# 4     1990-05      67.21          A      DEF        A  1763866    M
#
#                                             TITLE_FR  \
# 0  Indice des prix à la consommation - Base 2015 ...
# 1  Indice des prix à la consommation - Base 2015 ...
# 2  Indice des prix à la consommation - Base 2015 ...
# 3  Indice des prix à la consommation - Base 2015 ...
# 4  Indice des prix à la consommation - Base 2015 ...
#
#                                             TITLE_EN LAST_UPDATE  ...  \
# 0  Consumer price index - Base 2015 - All househo...  2025-12-12  ...
# 1  Consumer price index - Base 2015 - All househo...  2025-12-12  ...
# 2  Consumer price index - Base 2015 - All househo...  2025-12-12  ...
# 3  Consumer price index - Base 2015 - All househo...  2025-12-12  ...
# 4  Consumer price index - Base 2015 - All househo...  2025-12-12  ...
#
#   BASIND_label_fr  BASIND_label_en SERIE_ARRETEE_label_fr  \
# 0            2015             2015                    non
# 1            2015             2015                    non
# 2            2015             2015                    non
# 3            2015             2015                    non
# 4            2015             2015                    non
#
#    SERIE_ARRETEE_label_en OBS_STATUS_label_fr OBS_STATUS_label_en  \
# 0                      no      Valeur normale        Normal value
# 1                      no      Valeur normale        Normal value
# 2                      no      Valeur normale        Normal value
# 3                      no      Valeur normale        Normal value
# 4                      no      Valeur normale        Normal value
#
#   OBS_TYPE_label_fr OBS_TYPE_label_en  OBS_QUAL_label_fr  OBS_QUAL_label_en
# 0    Valeur normale      Normal value  Valeur définitive        Final value
# 1    Valeur normale      Normal value  Valeur définitive        Final value
# 2    Valeur normale      Normal value  Valeur définitive        Final value
# 3    Valeur normale      Normal value  Valeur définitive        Final value
# 4    Valeur normale      Normal value  Valeur définitive        Final value
#
# [5 rows x 56 columns]

# %%
# Sauvegarde IPC
fichier_ipc = os.path.join(DATA_DIR, 'ipc_france.csv')
df_ipc.to_csv(fichier_ipc, index=False)
print(f"Fichier sauvegardé : {fichier_ipc}")
# Out:
# Fichier sauvegardé : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data/ipc_france.csv

# %% [markdown]
# ### 3.3 Prix des logements (Indices Notaires-INSEE)

# %%
# Recherche des datasets sur les prix des logements
datasets_logement = rechercher_datasets('logement')
display(datasets_logement)
# Out:
# Recherche 'logement' : 6 résultat(s)
#                                 id  \
# 61          CONSTRUCTION-LOGEMENTS
# 124                      IPEA-2010
# 134                IPLA-IPLNA-2010
# 135                IPLA-IPLNA-2015
# 167                 PARC-LOGEMENTS
# 183  TCRED-CONDITIONSDEVIE-LOG-SOC
#
#                                                Name.fr  n_series
# 61                           Construction de logements       608
# 124  Indice des prix d’entretien-amélioration des l...        10
# 134  Indices des prix des logements neufs et indice...       112
# 135  Indices des prix des logements neufs et Indice...       142
# 167  Estimations annuelles du parc de logements (EAPL)        26
# 183                          TCRED - Logements sociaux       468

# %%
# Indices des prix des logements (Notaires-INSEE)
dataset_prix_log = 'IPLA-IPLNA-2015'

series_prix = get_series_list(dataset_prix_log)
print(f"Séries disponibles : {len(series_prix)}")
series_prix.head(10)
# Out:
# Séries disponibles : 142
#            DATASET     IDBANK                                         KEY  \
# 0  IPLA-IPLNA-2015  010567050      T.IPLA_A.INDICE.D95.SO.BRUT.2015.FALSE
# 1  IPLA-IPLNA-2015  010567051       T.IPLA_A.INDICE.D95.SO.CVS.2015.FALSE
# 2  IPLA-IPLNA-2015  010567052      T.IPLA_E.INDICE.D95.SO.BRUT.2015.FALSE
# 3  IPLA-IPLNA-2015  010567117   T.IPLA_A.INDICE.FR-D976.SO.CVS.2015.FALSE
# 4  IPLA-IPLNA-2015  010567118  T.IPLA_E.INDICE.FR-D976.SO.BRUT.2015.FALSE
# 5  IPLA-IPLNA-2015  010567119   T.IPLA_E.INDICE.FR-D976.SO.CVS.2015.FALSE
# 6  IPLA-IPLNA-2015  010567120  T.IPLA_M.INDICE.FR-D976.SO.BRUT.2015.FALSE
# 7  IPLA-IPLNA-2015  010567121   T.IPLA_M.INDICE.FR-D976.SO.CVS.2015.FALSE
# 8  IPLA-IPLNA-2015  010567122      T.IPLA_A.INDICE.R32.SO.BRUT.2015.FALSE
# 9  IPLA-IPLNA-2015  010567123       T.IPLA_A.INDICE.R32.SO.CVS.2015.FALSE
#
#   FREQ INDICATEUR  NATURE REF_AREA UNIT_MEASURE CORRECTION BASIND  ...  \
# 0    T     IPLA_A  INDICE      D95           SO       BRUT   2015  ...
# 1    T     IPLA_A  INDICE      D95           SO        CVS   2015  ...
# 2    T     IPLA_E  INDICE      D95           SO       BRUT   2015  ...
# 3    T     IPLA_A  INDICE  FR-D976           SO        CVS   2015  ...
# 4    T     IPLA_E  INDICE  FR-D976           SO       BRUT   2015  ...
# 5    T     IPLA_E  INDICE  FR-D976           SO        CVS   2015  ...
# 6    T     IPLA_M  INDICE  FR-D976           SO       BRUT   2015  ...
# 7    T     IPLA_M  INDICE  FR-D976           SO        CVS   2015  ...
# 8    T     IPLA_A  INDICE      R32           SO       BRUT   2015  ...
# 9    T     IPLA_A  INDICE      R32           SO        CVS   2015  ...
#
#      REF_AREA_label_fr         REF_AREA_label_en UNIT_MEASURE_label_fr  \
# 0      95 - Val-d'Oise           95 - Val-d'Oise            sans objet
# 1      95 - Val-d'Oise           95 - Val-d'Oise            sans objet
# 2      95 - Val-d'Oise           95 - Val-d'Oise            sans objet
# 3  France hors Mayotte  France excluding Mayotte            sans objet
# 4  France hors Mayotte  France excluding Mayotte            sans objet
# 5  France hors Mayotte  France excluding Mayotte            sans objet
# 6  France hors Mayotte  France excluding Mayotte            sans objet
# 7  France hors Mayotte  France excluding Mayotte            sans objet
# 8      Hauts-de-France           Hauts-de-France            sans objet
# 9      Hauts-de-France           Hauts-de-France            sans objet
#
#   UNIT_MEASURE_label_en                  CORRECTION_label_fr  \
# 0        not applicable                          Non corrigé
# 1        not applicable  Corrigé des variations saisonnières
# 2        not applicable                          Non corrigé
# 3        not applicable  Corrigé des variations saisonnières
# 4        not applicable                          Non corrigé
# 5        not applicable  Corrigé des variations saisonnières
# 6        not applicable                          Non corrigé
# 7        not applicable  Corrigé des variations saisonnières
# 8        not applicable                          Non corrigé
# 9        not applicable  Corrigé des variations saisonnières
#
#   CORRECTION_label_en BASIND_label_fr BASIND_label_en SERIE_ARRETEE_label_fr  \
# 0         Uncorrected            2015            2015                    non
# 1   Seasonal adjusted            2015            2015                    non
# 2         Uncorrected            2015            2015                    non
# 3   Seasonal adjusted            2015            2015                    non
# 4         Uncorrected            2015            2015                    non
# 5   Seasonal adjusted            2015            2015                    non
# 6         Uncorrected            2015            2015                    non
# 7   Seasonal adjusted            2015            2015                    non
# 8         Uncorrected            2015            2015                    non
# 9   Seasonal adjusted            2015            2015                    non
#
#   SERIE_ARRETEE_label_en
# 0                     no
# 1                     no
# 2                     no
# 3                     no
# 4                     no
# 5                     no
# 6                     no
# 7                     no
# 8                     no
# 9                     no
#
# [10 rows x 27 columns]

# %%
# Chargement ou extraction des prix des logements
fichier_prix = os.path.join(DATA_DIR, 'prix_logements_indices.csv')

if os.path.exists(fichier_prix):
    df_prix_log = pd.read_csv(fichier_prix)
    print(f"Prix logements chargé : {df_prix_log.shape[0]} lignes")
    print(f"Période : {df_prix_log['TIME_PERIOD'].min()} à {df_prix_log['TIME_PERIOD'].max()}")
else:
    idbanks_prix = series_prix['IDBANK'].tolist()
    df_prix_log = get_series(idbanks_prix)
    print(f"Prix logements extrait : {df_prix_log.shape}")

df_prix_log.head()
# Out:
# Prix logements chargé : 15296 lignes
# Période : 1992-Q1 à 2025-Q3
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_QUAL OBS_TYPE    IDBANK FREQ  \
# 0     2000-Q1       47.7          A      DEF        A  10001868    T
# 1     2000-Q2       49.1          A      DEF        A  10001868    T
# 2     2000-Q3       50.8          A      DEF        A  10001868    T
# 3     2000-Q4       50.6          A      DEF        A  10001868    T
# 4     2001-Q1       51.2          A      DEF        A  10001868    T
#
#                                             TITLE_FR  \
# 0  Indice des prix des logements (neufs et ancien...
# 1  Indice des prix des logements (neufs et ancien...
# 2  Indice des prix des logements (neufs et ancien...
# 3  Indice des prix des logements (neufs et ancien...
# 4  Indice des prix des logements (neufs et ancien...
#
#                                             TITLE_EN LAST_UPDATE  ...  \
# 0  House price index (new and second-hand) – Raw ...  2025-12-19  ...
# 1  House price index (new and second-hand) – Raw ...  2025-12-19  ...
# 2  House price index (new and second-hand) – Raw ...  2025-12-19  ...
# 3  House price index (new and second-hand) – Raw ...  2025-12-19  ...
# 4  House price index (new and second-hand) – Raw ...  2025-12-19  ...
#
#   OBS_STATUS_label_fr  OBS_STATUS_label_en OBS_REV_label_fr  OBS_REV_label_en  \
# 0      Valeur normale         Normal value              NaN               NaN
# 1      Valeur normale         Normal value              NaN               NaN
# 2      Valeur normale         Normal value              NaN               NaN
# 3      Valeur normale         Normal value              NaN               NaN
# 4      Valeur normale         Normal value              NaN               NaN
#
#    OBS_CONF_label_fr OBS_CONF_label_en OBS_TYPE_label_fr OBS_TYPE_label_en  \
# 0                NaN               NaN    Valeur normale      Normal value
# 1                NaN               NaN    Valeur normale      Normal value
# 2                NaN               NaN    Valeur normale      Normal value
# 3                NaN               NaN    Valeur normale      Normal value
# 4                NaN               NaN    Valeur normale      Normal value
#
#    OBS_QUAL_label_fr OBS_QUAL_label_en
# 0  Valeur définitive       Final value
# 1  Valeur définitive       Final value
# 2  Valeur définitive       Final value
# 3  Valeur définitive       Final value
# 4  Valeur définitive       Final value
#
# [5 rows x 50 columns]

# %%
# Sauvegarde
fichier_prix = os.path.join(DATA_DIR, 'prix_logements_indices.csv')
df_prix_log.to_csv(fichier_prix, index=False)
print(f"Fichier sauvegardé : {fichier_prix}")
# Out:
# Fichier sauvegardé : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data/prix_logements_indices.csv

# %% [markdown]
# ---
#
# ## 4. Données de chômage
#
# ### 4.1 Chômage national

# %%
# Dataset chômage
dataset_chomage = 'CHOMAGE-TRIM-NATIONAL'

series_chomage = get_series_list(dataset_chomage)
print(f"Dataset : {dataset_chomage}")
print(f"Nombre de séries : {len(series_chomage)}")
series_chomage.head()
# Out:
# Dataset : CHOMAGE-TRIM-NATIONAL
# Nombre de séries : 169
#                  DATASET     IDBANK  \
# 0  CHOMAGE-TRIM-NATIONAL  001688537
# 1  CHOMAGE-TRIM-NATIONAL  001688538
# 2  CHOMAGE-TRIM-NATIONAL  001688531
# 3  CHOMAGE-TRIM-NATIONAL  001688536
# 4  CHOMAGE-TRIM-NATIONAL  001688535
#
#                                                KEY FREQ INDICATEUR NATURE  \
# 0  T.CTTXC.TAUX.FR-D976.0.00-24.POURCENT.CVS.FALSE    T      CTTXC   TAUX
# 1       T.CTTXC.TAUX.FM.2.25-49.POURCENT.CVS.FALSE    T      CTTXC   TAUX
# 2    T.CTTXC.TAUX.FR-D976.0.50-.POURCENT.CVS.FALSE    T      CTTXC   TAUX
# 3       T.CTTXC.TAUX.FM.0.00-24.POURCENT.CVS.FALSE    T      CTTXC   TAUX
# 4    T.CTTXC.TAUX.FR-D976.1.00-.POURCENT.CVS.FALSE    T      CTTXC   TAUX
#
#   REF_AREA SEXE    AGE UNIT_MEASURE  ... SEXE_label_fr SEXE_label_en  \
# 0  FR-D976    0  00-24     POURCENT  ...      Ensemble           All
# 1       FM    2  25-49     POURCENT  ...        Femmes         Women
# 2  FR-D976    0    50-     POURCENT  ...      Ensemble           All
# 3       FM    0  00-24     POURCENT  ...      Ensemble           All
# 4  FR-D976    1    00-     POURCENT  ...        Hommes           Men
#
#       AGE_label_fr             AGE_label_en UNIT_MEASURE_label_fr  \
# 0  Moins de 25 ans       Below 25 years old                     %
# 1   De 25 à 49 ans  From 25 to 49 years old                     %
# 2   50 ans et plus    50 years old and over                     %
# 3  Moins de 25 ans       Below 25 years old                     %
# 4         Ensemble                 All ages                     %
#
#   UNIT_MEASURE_label_en                  CORRECTION_label_fr  \
# 0                     %  Corrigé des variations saisonnières
# 1                     %  Corrigé des variations saisonnières
# 2                     %  Corrigé des variations saisonnières
# 3                     %  Corrigé des variations saisonnières
# 4                     %  Corrigé des variations saisonnières
#
#   CORRECTION_label_en SERIE_ARRETEE_label_fr SERIE_ARRETEE_label_en
# 0   Seasonal adjusted                    non                     no
# 1   Seasonal adjusted                    non                     no
# 2   Seasonal adjusted                    non                     no
# 3   Seasonal adjusted                    non                     no
# 4   Seasonal adjusted                    non                     no
#
# [5 rows x 30 columns]

# %%
# Chargement ou extraction du chômage national
fichier_chomage = os.path.join(DATA_DIR, 'chomage_series.csv')

if os.path.exists(fichier_chomage):
    df_chomage = pd.read_csv(fichier_chomage)
    print(f"Chômage national chargé : {df_chomage.shape[0]} lignes")
    print(f"Période : {df_chomage['TIME_PERIOD'].min()} à {df_chomage['TIME_PERIOD'].max()}")
else:
    idbanks_chomage = series_chomage['IDBANK'].tolist()
    df_chomage = get_series(idbanks_chomage)
    print(f"Chômage national extrait : {df_chomage.shape}")

df_chomage.head()
# Out:
# Chômage national chargé : 19130 lignes
# Période : 1975-Q1 à 2025-Q3
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_QUAL OBS_TYPE   IDBANK FREQ  \
# 0     1975-Q1      644.0          A      DEF        A  1688358    T
# 1     1975-Q2      718.0          A      DEF        A  1688358    T
# 2     1975-Q3      790.0          A      DEF        A  1688358    T
# 3     1975-Q4      812.0          A      DEF        A  1688358    T
# 4     1976-Q1      822.0          A      DEF        A  1688358    T
#
#                                             TITLE_FR  \
# 0  Chômeurs au sens du BIT - Ensemble (en millier...
# 1  Chômeurs au sens du BIT - Ensemble (en millier...
# 2  Chômeurs au sens du BIT - Ensemble (en millier...
# 3  Chômeurs au sens du BIT - Ensemble (en millier...
# 4  Chômeurs au sens du BIT - Ensemble (en millier...
#
#                                             TITLE_EN LAST_UPDATE  ...  \
# 0  ILO unemployed - All (in thousands) - Metropol...  2019-08-14  ...
# 1  ILO unemployed - All (in thousands) - Metropol...  2019-08-14  ...
# 2  ILO unemployed - All (in thousands) - Metropol...  2019-08-14  ...
# 3  ILO unemployed - All (in thousands) - Metropol...  2019-08-14  ...
# 4  ILO unemployed - All (in thousands) - Metropol...  2019-08-14  ...
#
#   SERIE_ARRETEE_label_fr  SERIE_ARRETEE_label_en OBS_STATUS_label_fr  \
# 0                    oui                     yes      Valeur normale
# 1                    oui                     yes      Valeur normale
# 2                    oui                     yes      Valeur normale
# 3                    oui                     yes      Valeur normale
# 4                    oui                     yes      Valeur normale
#
#    OBS_STATUS_label_en  OBS_REV_label_fr OBS_REV_label_en OBS_TYPE_label_fr  \
# 0         Normal value               NaN              NaN    Valeur normale
# 1         Normal value               NaN              NaN    Valeur normale
# 2         Normal value               NaN              NaN    Valeur normale
# 3         Normal value               NaN              NaN    Valeur normale
# 4         Normal value               NaN              NaN    Valeur normale
#
#   OBS_TYPE_label_en  OBS_QUAL_label_fr OBS_QUAL_label_en
# 0      Normal value  Valeur définitive       Final value
# 1      Normal value  Valeur définitive       Final value
# 2      Normal value  Valeur définitive       Final value
# 3      Normal value  Valeur définitive       Final value
# 4      Normal value  Valeur définitive       Final value
#
# [5 rows x 50 columns]

# %%
# Sauvegarde
fichier_chomage = os.path.join(DATA_DIR, 'chomage_series.csv')
df_chomage.to_csv(fichier_chomage, index=False)
print(f"Fichier sauvegardé : {fichier_chomage}")
# Out:
# Fichier sauvegardé : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data/chomage_series.csv

# %% [markdown]
# ### 4.2 Chômage par département (taux localisé)

# %%
# Taux de chômage localisé (par département/région)
dataset_chomage_loc = 'TAUX-CHOMAGE'

series_chomage_loc = get_series_list(dataset_chomage_loc)
print(f"Dataset : {dataset_chomage_loc}")
print(f"Nombre de séries : {len(series_chomage_loc)}")
series_chomage_loc.head(10)
# Out:
# Dataset : TAUX-CHOMAGE
# Nombre de séries : 115
#         DATASET     IDBANK                                                KEY  \
# 0  TAUX-CHOMAGE  001515957  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D93.POURCEN...
# 1  TAUX-CHOMAGE  001515956  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D92.POURCEN...
# 2  TAUX-CHOMAGE  001515955  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D91.POURCEN...
# 3  TAUX-CHOMAGE  001515954  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D90.POURCEN...
# 4  TAUX-CHOMAGE  001515953  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D89.POURCEN...
# 5  TAUX-CHOMAGE  001515949  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D85.POURCEN...
# 6  TAUX-CHOMAGE  001515951  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D87.POURCEN...
# 7  TAUX-CHOMAGE  001515950  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D86.POURCEN...
# 8  TAUX-CHOMAGE  001515948  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D84.POURCEN...
# 9  TAUX-CHOMAGE  001515947  T.TAUX_CHOMAGE_LOCALISE.PROPORTION.D82.POURCEN...
#
#   FREQ             INDICATEUR      NATURE REF_AREA UNIT_MEASURE CORRECTION  \
# 0    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D93     POURCENT        CVS
# 1    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D92     POURCENT        CVS
# 2    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D91     POURCENT        CVS
# 3    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D90     POURCENT        CVS
# 4    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D89     POURCENT        CVS
# 5    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D85     POURCENT        CVS
# 6    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D87     POURCENT        CVS
# 7    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D86     POURCENT        CVS
# 8    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D84     POURCENT        CVS
# 9    T  TAUX_CHOMAGE_LOCALISE  PROPORTION      D82     POURCENT        CVS
#
#    FREQ_label_fr  ...       INDICATEUR_label_fr           INDICATEUR_label_en  \
# 0  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 1  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 2  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 3  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 4  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 5  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 6  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 7  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 8  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
# 9  Trimestrielle  ...  Taux de chômage localisé  Unemployment rates localized
#
#   NATURE_label_fr NATURE_label_en           REF_AREA_label_fr  \
# 0      Proportion      Proportion      93 - Seine-Saint-Denis
# 1      Proportion      Proportion         92 - Hauts-de-Seine
# 2      Proportion      Proportion                91 - Essonne
# 3      Proportion      Proportion  90 - Territoire de Belfort
# 4      Proportion      Proportion                  89 - Yonne
# 5      Proportion      Proportion                 85 - Vendée
# 6      Proportion      Proportion           87 - Haute-Vienne
# 7      Proportion      Proportion                 86 - Vienne
# 8      Proportion      Proportion               84 - Vaucluse
# 9      Proportion      Proportion        82 - Tarn-et-Garonne
#
#             REF_AREA_label_en UNIT_MEASURE_label_fr UNIT_MEASURE_label_en  \
# 0      93 - Seine-Saint-Denis                     %                     %
# 1         92 - Hauts-de-Seine                     %                     %
# 2                91 - Essonne                     %                     %
# 3  90 - Territoire de Belfort                     %                     %
# 4                  89 - Yonne                     %                     %
# 5                 85 - Vendée                     %                     %
# 6           87 - Haute-Vienne                     %                     %
# 7                 86 - Vienne                     %                     %
# 8               84 - Vaucluse                     %                     %
# 9        82 - Tarn-et-Garonne                     %                     %
#
#                    CORRECTION_label_fr CORRECTION_label_en
# 0  Corrigé des variations saisonnières   Seasonal adjusted
# 1  Corrigé des variations saisonnières   Seasonal adjusted
# 2  Corrigé des variations saisonnières   Seasonal adjusted
# 3  Corrigé des variations saisonnières   Seasonal adjusted
# 4  Corrigé des variations saisonnières   Seasonal adjusted
# 5  Corrigé des variations saisonnières   Seasonal adjusted
# 6  Corrigé des variations saisonnières   Seasonal adjusted
# 7  Corrigé des variations saisonnières   Seasonal adjusted
# 8  Corrigé des variations saisonnières   Seasonal adjusted
# 9  Corrigé des variations saisonnières   Seasonal adjusted
#
# [10 rows x 21 columns]

# %%
# Chargement ou extraction du chômage localisé
fichier_chomage_dept = os.path.join(DATA_DIR, 'chomage_departements_complet.csv')

if os.path.exists(fichier_chomage_dept):
    df_chomage_dept = pd.read_csv(fichier_chomage_dept)
    print(f"Chômage localisé chargé : {df_chomage_dept.shape[0]} lignes")
    print(f"Période : {df_chomage_dept['TIME_PERIOD'].min()} à {df_chomage_dept['TIME_PERIOD'].max()}")
else:
    idbanks_chomage_loc = series_chomage_loc['IDBANK'].tolist()
    df_chomage_dept = get_series(idbanks_chomage_loc)
    print(f"Chômage localisé extrait : {df_chomage_dept.shape}")

df_chomage_dept.head()
# Out:
# Chômage localisé chargé : 16988 lignes
# Période : 1982-Q1 à 2025-Q3
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_QUAL OBS_TYPE   IDBANK FREQ  \
# 0     1982-Q1        5.2          A      DEF        A  1515862    T
# 1     1982-Q2        5.3          A      DEF        A  1515862    T
# 2     1982-Q3        5.5          A      DEF        A  1515862    T
# 3     1982-Q4        5.5          A      DEF        A  1515862    T
# 4     1983-Q1        5.6          A      DEF        A  1515862    T
#
#                                             TITLE_FR  \
# 0  Taux de chômage localisé par département - Ave...
# 1  Taux de chômage localisé par département - Ave...
# 2  Taux de chômage localisé par département - Ave...
# 3  Taux de chômage localisé par département - Ave...
# 4  Taux de chômage localisé par département - Ave...
#
#                                             TITLE_EN LAST_UPDATE  ...  \
# 0  Unemployment rates localized by department - A...  2025-12-19  ...
# 1  Unemployment rates localized by department - A...  2025-12-19  ...
# 2  Unemployment rates localized by department - A...  2025-12-19  ...
# 3  Unemployment rates localized by department - A...  2025-12-19  ...
# 4  Unemployment rates localized by department - A...  2025-12-19  ...
#
#   OBS_STATUS_label_fr  OBS_STATUS_label_en OBS_REV_label_fr  OBS_REV_label_en  \
# 0      Valeur normale         Normal value              NaN               NaN
# 1      Valeur normale         Normal value              NaN               NaN
# 2      Valeur normale         Normal value              NaN               NaN
# 3      Valeur normale         Normal value              NaN               NaN
# 4      Valeur normale         Normal value              NaN               NaN
#
#    OBS_TYPE_label_fr OBS_TYPE_label_en  OBS_QUAL_label_fr OBS_QUAL_label_en  \
# 0     Valeur normale      Normal value  Valeur définitive       Final value
# 1     Valeur normale      Normal value  Valeur définitive       Final value
# 2     Valeur normale      Normal value  Valeur définitive       Final value
# 3     Valeur normale      Normal value  Valeur définitive       Final value
# 4     Valeur normale      Normal value  Valeur définitive       Final value
#
#   DEPT_CODE     REGION
# 0        12  Occitanie
# 1        12  Occitanie
# 2        12  Occitanie
# 3        12  Occitanie
# 4        12  Occitanie
#
# [5 rows x 43 columns]

# %%
# Sauvegarde chômage départements
fichier_chomage_dept = os.path.join(DATA_DIR, 'chomage_departements_complet.csv')
df_chomage_dept.to_csv(fichier_chomage_dept, index=False)
print(f"Fichier sauvegardé : {fichier_chomage_dept}")
print(f"Taille : {os.path.getsize(fichier_chomage_dept) / 1024:.1f} KB")
# Out:
# Fichier sauvegardé : /home/tinkerbell/Desktop/DataScientest/Compagnon Immobilier - Datascientest/Economie_Demographie/data/chomage_departements_complet.csv
# Taille : 9874.0 KB

# %% [markdown]
# ---
#
# ## 5. Données locales (par département)
#
# ### 5.1 Population

# %%
# Liste des codes départements français
codes_departements = [f"{i:02d}" for i in range(1, 96) if i != 20]  # 01 à 95 sauf 20
codes_departements.extend(['2A', '2B'])  # Corse
codes_departements.extend(['971', '972', '973', '974', '976'])  # DOM

print(f"Nombre de départements : {len(codes_departements)}")
print(f"Premiers codes : {codes_departements[:10]}")
# Out:
# Nombre de départements : 101
# Premiers codes : ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']

# %%
# Chargement des données de population
fichier_pop = os.path.join(DATA_DIR, 'population_departements.csv')

if os.path.exists(fichier_pop):
    df_pop = pd.read_csv(fichier_pop)
    print(f"Population chargé : {df_pop.shape[0]} lignes")
    display(df_pop.head())
else:
    print("Extraction population via get_local_data...")
    try:
        df_pop = get_local_data(
            variables='SEXE',
            dataset_version='GEO2024RP2021',
            nivgeo='DEP',
            geocodes=codes_departements[:5]
        )
        print(f"Population extrait : {df_pop.shape}")
    except Exception as e:
        print(f"Erreur : {e}")
# Out:
# Population chargé : 2003 lignes
#   CODEGEO NIVGEO        UNIT_label_fr   UNIT STOCD      OBS_VALUE  \
# 0      01    DEP  Nombre de logements  NBLOG   ENS  274538.375368
# 1      01    DEP  Nombre de logements  NBLOG    10  171307.121971
# 2      01    DEP  Nombre de logements  NBLOG    21   54028.486208
# 3      01    DEP  Nombre de logements  NBLOG    22   39004.585669
# 4      01    DEP  Nombre de logements  NBLOG    23    5205.883730
#
#                        STOCD_label DATASET_VERSION  \
# 0  Statut d'occupation du logement   GEO2021RP2018
# 1  Statut d'occupation du logement   GEO2021RP2018
# 2  Statut d'occupation du logement   GEO2021RP2018
# 3  Statut d'occupation du logement   GEO2021RP2018
# 4  Statut d'occupation du logement   GEO2021RP2018
#
#                    DATASET_NAME  DATA_DATE
# 0  Recensement de la population     2018.0
# 1  Recensement de la population     2018.0
# 2  Recensement de la population     2018.0
# 3  Recensement de la population     2018.0
# 4  Recensement de la population     2018.0

# %% [markdown]
# ### 5.2 Revenus (FILOSOFI)

# %%
# Les données de revenus sont souvent dans des datasets spécifiques
# FILOSOFI (Fichier Localisé Social et Fiscal)

datasets_revenus = rechercher_datasets('revenu')
display(datasets_revenus)
# Out:
# Recherche 'revenu' : 5 résultat(s)
#                                          id  \
# 15                             CNA-2010-RDB
# 30                             CNA-2014-RDB
# 204              TCRED-SALAIRES-REVENUS-MEN
# 206  TCRED-SALAIRES-REVENUS-REV-SAL-SEXE-CS
# 207    TCRED-SALAIRES-REVENUS-STRUCTURE-RDB
#
#                                                Name.fr  n_series
# 15   Revenu et pouvoir d’achat des ménages - Résult...        11
# 30               Revenu et pouvoir d’achat des ménages        12
# 204            TCRED - Revenus disponibles des ménages       565
# 206  TCRED - Revenu salarial annuel moyen selon la ...       819
# 207             TCRED - Structure du revenu disponible       565

# %%
# Chargement des données de revenus
fichier_revenus = os.path.join(DATA_DIR, 'revenus_departements.csv')

if os.path.exists(fichier_revenus):
    df_revenus = pd.read_csv(fichier_revenus)
    print(f"Revenus chargé : {df_revenus.shape[0]} lignes")
    display(df_revenus.head())
else:
    print("Fichier revenus_departements.csv non trouvé")
    print("Extraction via get_local_data (peut être long)...")
    try:
        df_revenus = get_local_data(
            variables='REVENU',
            dataset_version='GEO2024FILOSOFI2021',
            nivgeo='DEP',
            geocodes=codes_departements
        )
        print(f"Revenus extrait : {df_revenus.shape}")
    except Exception as e:
        print(f"Erreur : {e}")
# Out:
# Revenus chargé : 1770 lignes
#   CODEGEO NIVGEO                 UNIT_label_fr     UNIT  INDICS_FILO_DISP  \
# 0      01    DEP     Nombre de ménages fiscaux    NBMEN               1.0
# 1      01    DEP  Nombre de personnes fiscales   NBPERS               1.0
# 2      01    DEP                       Médiane  MEDIANE               1.0
# 3      02    DEP     Nombre de ménages fiscaux    NBMEN               1.0
# 4      02    DEP  Nombre de personnes fiscales   NBPERS               1.0
#
#    OBS_VALUE             INDICS_FILO_DISP_label  DATASET_VERSION  \
# 0   258018.0  Indicateur de revenus disponibles  GEO2021FILO2018
# 1   618263.0  Indicateur de revenus disponibles  GEO2021FILO2018
# 2    23420.0  Indicateur de revenus disponibles  GEO2021FILO2018
# 3   221370.0  Indicateur de revenus disponibles  GEO2021FILO2018
# 4   512838.0  Indicateur de revenus disponibles  GEO2021FILO2018
#
#                         DATASET_NAME  DATA_DATE  INDICS_FILO_DISP_DET  \
# 0  Fichier localisé social et fiscal     2018.0                   NaN
# 1  Fichier localisé social et fiscal     2018.0                   NaN
# 2  Fichier localisé social et fiscal     2018.0                   NaN
# 3  Fichier localisé social et fiscal     2018.0                   NaN
# 4  Fichier localisé social et fiscal     2018.0                   NaN
#
#   INDICS_FILO_DISP_DET_label
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %% [markdown]
# ---
#
# ## 6. Récapitulatif des fichiers extraits

# %%
# Récapitulatif de tous les fichiers dans le dossier data
print("=" * 80)
print("FICHIERS DE DONNÉES DISPONIBLES")
print("=" * 80)

fichiers_csv = [f for f in os.listdir(DATA_DIR) if f.endswith('.csv')]
fichiers_csv.sort()

total_size = 0
for f in fichiers_csv:
    chemin = os.path.join(DATA_DIR, f)
    size = os.path.getsize(chemin) / 1024
    total_size += size
    
    # Charger pour avoir le nombre de lignes
    try:
        df = pd.read_csv(chemin, sep=';')
    except:
        df = pd.read_csv(chemin)
    print(f"{f:45} | {size:8.1f} KB | {len(df):7} lignes | {len(df.columns):2} cols")

print("=" * 80)
print(f"Total : {len(fichiers_csv)} fichiers | {total_size/1024:.1f} MB")
# Out:
# ================================================================================
# FICHIERS DE DONNÉES DISPONIBLES
# ================================================================================
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[24], line 16
#      13     total_size += size
#      15     # Charger pour avoir le nombre de lignes
# ---> 16     df = pd.read_csv(chemin)
#      17     print(f"{f:45} | {size:8.1f} KB | {len(df):7} lignes | {len(df.columns):2} cols")
#      19 print("=" * 80)
#
# File ~/Desktop/DataScientest/Compagnon Immobilier - Datascientest/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/DataScientest/Compagnon Immobilier - Datascientest/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Desktop/DataScientest/Compagnon Immobilier - Datascientest/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Desktop/DataScientest/Compagnon Immobilier - Datascientest/venv/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 4, saw 231

# %% [markdown]
# ### 6.1 Construction de logements (permis et mises en chantier)

# %%
# Construction de logements - permis de construire et mises en chantier
fichier_constr = os.path.join(DATA_DIR, 'construction_logements.csv')

if os.path.exists(fichier_constr):
    df_constr = pd.read_csv(fichier_constr)
    print(f"Construction logements chargé : {df_constr.shape[0]} lignes")
    print(f"Période : {df_constr['TIME_PERIOD'].min()} à {df_constr['TIME_PERIOD'].max()}")
else:
    series_constr = get_series_list('CONSTRUCTION-LOGEMENTS')
    # Filtrer sur France et régions, ensemble des logements
    series_filtre = series_constr[
        (series_constr['REF_AREA'].str.startswith('FM') | series_constr['REF_AREA'].str.startswith('R')) &
        (series_constr['LOGEMENT'] == '0')
    ]
    idbanks = series_filtre['IDBANK'].tolist()
    df_constr = get_series(idbanks)
    df_constr.to_csv(fichier_constr, index=False)
    print(f"Construction logements extrait : {df_constr.shape[0]} lignes")

df_constr.head()

# %% [markdown]
# ### 6.2 Parc de logements (stock annuel)

# %%
# Parc de logements - estimations annuelles (EAPL)
fichier_parc = os.path.join(DATA_DIR, 'parc_logements.csv')

if os.path.exists(fichier_parc):
    df_parc = pd.read_csv(fichier_parc)
    print(f"Parc logements chargé : {df_parc.shape[0]} lignes")
    print(f"Période : {df_parc['TIME_PERIOD'].min()} à {df_parc['TIME_PERIOD'].max()}")
else:
    series_parc = get_series_list('PARC-LOGEMENTS')
    idbanks = series_parc['IDBANK'].tolist()
    df_parc = get_series(idbanks)
    df_parc.to_csv(fichier_parc, index=False)
    print(f"Parc logements extrait : {df_parc.shape[0]} lignes")

df_parc.head()

# %% [markdown]
# ---
#
# ## 7. Limites des données extraites
#
# Certaines données présentent des limites qu'il faut prendre en compte pour l'analyse :
#
# | Donnée | Limite | Solution appliquée |
# |--------|--------|-------------------|
# | **Revenus ménages (API)** | 2012-2015 uniquement | FILOSOFI 2021 téléchargé manuellement |
# | **Pauvreté (API)** | 2012-2015 uniquement | FILOSOFI 2021 téléchargé manuellement |
# | **Prix logements** | 32 zones seulement | Données DVF gérées par un collègue |
# | **FILOSOFI via API** | 2018 max | Téléchargement direct depuis insee.fr |
#
# ### Données complémentaires intégrées
#
# - **FILOSOFI 2021** : Revenus et pauvreté par commune (téléchargé depuis https://www.insee.fr/fr/statistiques/6692392)
# - **Construction logements** : Permis et mises en chantier (API INSEE)
# - **Parc logements** : Stock annuel par catégorie (API INSEE)
#
# ### Note sur les prix immobiliers
#
# Les données DVF (Demandes de Valeurs Foncières) au niveau communal sont gérées par un autre membre de l'équipe via https://app.dvf.etalab.gouv.fr/

# %% [markdown]
# ---
#
# ## 8. Fonction utilitaire
#
# Fonction réutilisable pour extraire et sauvegarder un dataset :

# %%
def extraire_et_sauvegarder(dataset_id, nom_fichier, dossier=DATA_DIR):
    """
    Extrait un dataset INSEE et le sauvegarde en CSV.
    
    Paramètres:
        dataset_id (str): Identifiant du dataset INSEE
        nom_fichier (str): Nom du fichier de sortie (avec .csv)
        dossier (str): Dossier de destination
    
    Retourne:
        DataFrame ou None en cas d'erreur
    """
    try:
        print(f"Extraction de {dataset_id}...")
        
        # 1. Récupérer la liste des séries et leurs IDBANK
        series_list = get_series_list(dataset_id)
        idbanks = series_list['IDBANK'].tolist()
        print(f"  -> {len(idbanks)} séries trouvées")
        
        # 2. Extraire les données
        df = get_series(idbanks)
        
        # 3. Sauvegarde
        chemin = os.path.join(dossier, nom_fichier)
        df.to_csv(chemin, index=False)
        
        print(f"  -> {len(df)} lignes extraites")
        print(f"  -> Sauvegardé : {nom_fichier}")
        
        return df
        
    except Exception as e:
        print(f"  -> Erreur : {e}")
        return None

# %%
# Exemple d'utilisation
# extraire_et_sauvegarder('CNT-2020-PIB-EQB-RF', 'pib_france_test.csv')

# %% [markdown]
# ---
#
# ## Bilan
#
# **Sources de données extraites :**
#
# | Source | Fichiers | Contenu |
# |--------|----------|---------|
# | API INSEE (pynsee) | 14 fichiers | PIB, IPC, chômage, population, emploi, prix logements |
# | Téléchargement INSEE | 6 fichiers | FILOSOFI 2021 (revenus et pauvreté par commune) |
# | API INSEE | 2 fichiers | Construction et parc de logements |
#
# Ces données devront être nettoyées et harmonisées dans le notebook suivant (`03_nettoyage_donnees.ipynb`).
